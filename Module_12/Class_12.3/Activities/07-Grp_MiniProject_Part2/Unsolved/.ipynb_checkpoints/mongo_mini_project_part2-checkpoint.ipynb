# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# assign the met database to a variable name
db = mongo['met']

# assign the collection to a variable
artifacts = db['artifacts']

# %% [markdown]
# * Write a query that:
#
#     * Uses `find()` to find documents about artifacts that come from the "Maya" culture and returns the following fields: `accessionNumber`, `accessionYear`, `classification`, `country`, `department`, `measurements.elementMeasurements.Height`, `measurements.elementMeasurements.Width`, `measurements.elementMeasurements.Depth`, `medium`, `title`,`objectURL`.
#
#     * Uses `sort()` to sort by the artifact's height.
#
#     * Uses `limit()` to limit the number of results to 5.

# %%
# Query
query = {'culture': 'Maya'}

fields = {'accessionNumber': 1, 'accessionYear': 1, 'classification': 1, 'country': 1, 
          'measurements.elementMeasurements.Height': 1, 'measurements.elementMeasurements.Width': 1,
         'measurements.elementMeasurements.Depth': 1, 'medium:': 1, 'title': 1, 'objectURL': 1}

# Cast the results as a list and save them to a variable
mayan_items = list(artifacts.find(query, fields))

# Pretty print the results
pprint(mayan_items)
# Out:
# [{'_id': ObjectId('64b5c397eb87d19a04edc05e'),
#   'accessionNumber': '1979.206.1061',
#   'accessionYear': '1979',
#   'classification': 'Stone-Sculpture',
#   'country': 'Guatemala',
#   'measurements': [{'elementMeasurements': {'Depth': 5.08,
#                                             'Height': 23.9713,
#                                             'Width': 26.67}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/313254',
#   'title': 'Animal Head Hacha'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc1c5'),
#   'accessionNumber': '1987.450.1',
#   'accessionYear': '1987',
#   'classification': 'Ceramics-Containers',
#   'country': 'Guatemala or Mexico',
#   'measurements': [{'elementMeasurements': {'Height': 10.477521}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/315883',
#   'title': 'Bowl, Mythological Scene'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc214'),
#   'accessionNumber': '1999.484.1a, b',
#   'accessionYear': '1999',
#   'classification': 'Ceramics-Containers',
#   'country': 'Guatemala',
#   'measurements': [{'elementMeasurements': {'Depth': 22.860046,
#                                             'Height': 80.01016,
#                                             'Width': 31.115063}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/318345',
#   'title': 'Censer, Seated King'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc21e'),
#   'accessionNumber': '1978.412.90a, b',
#   'accessionYear': '1978',
#   'classification': 'Ceramics-Containers',
#   'country': 'Guatemala or Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 13.335027,
#                                             'Height': 30.16256,
#                                             'Width': 19.68504}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/310542',
#   'title': 'Whistling vessel'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc23a'),
#   'accessionNumber': '1978.412.206',
#   'accessionYear': '1978',
#   'classification': 'Ceramics-Containers',
#   'country': '',
#   'measurements': [{'elementMeasurements': {'Depth': 10.636271,
#                                             'Height': 13.970028,
#                                             'Width': 10.16002}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/310364',
#   'title': 'Vessel, mythological scene'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc23f'),
#   'accessionNumber': '1979.206.1047',
#   'accessionYear': '1979',
#   'classification': 'Stone-Sculpture',
#   'country': 'Guatemala or Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 6.99,
#                                             'Height': 88.9,
#                                             'Width': 87.63}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/313240',
#   'title': 'Relief with Enthroned Ruler'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc24d'),
#   'accessionNumber': '1979.206.1063',
#   'accessionYear': '1979',
#   'classification': 'Wood-Sculpture',
#   'country': 'Guatemala or Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 22.86,
#                                             'Height': 35.8775,
#                                             'Width': 22.86}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/313256',
#   'title': 'Mirror-Bearer'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc3a1'),
#   'accessionNumber': '1978.412.99',
#   'accessionYear': '1978',
#   'classification': 'Ceramics-Sculpture',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 34.93}},
#                    {'elementMeasurements': {'Depth': 34.93,
#                                             'Height': 53.975,
#                                             'Width': 28.91}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/310551',
#   'title': 'Censer Support'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc448'),
#   'accessionNumber': '1979.206.951',
#   'accessionYear': '1979',
#   'classification': 'Shell-Ornaments',
#   'country': 'Guatemala or Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 2.54}},
#                    {'elementMeasurements': {'Depth': 2.54,
#                                             'Height': 9.525,
#                                             'Width': 5.99}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/313149',
#   'title': 'Canine Ornament'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc45a'),
#   'accessionNumber': '1979.206.1143',
#   'accessionYear': '1979',
#   'classification': 'Ceramics-Musical Instruments',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 18.7325,
#                                             'Height': 5.08,
#                                             'Width': 8.51}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/313335',
#   'title': 'Crocodile Rattle'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc46e'),
#   'accessionNumber': '1978.412.159',
#   'accessionYear': '1978',
#   'classification': 'Ceramics-Containers',
#   'country': 'Guatemala',
#   'measurements': [{'elementMeasurements': {'Height': 22.225044}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/310607',
#   'title': 'Vessel, Seated Deities'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc47b'),
#   'accessionNumber': '66.181',
#   'accessionYear': '1966',
#   'classification': 'Stone-Sculpture',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 50.800102,
#                                             'Height': 215.58293,
#                                             'Width': 60.96012}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/309404',
#   'title': 'Monumental figure (Chahk)'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4c0'),
#   'accessionNumber': '1979.206.1132',
#   'accessionYear': '1979',
#   'classification': 'Stone-Sculpture',
#   'country': 'Mexico or Guatemala',
#   'measurements': [{'elementMeasurements': {'Depth': 4.45,
#                                             'Height': 13.97,
#                                             'Width': 2.84}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/313325',
#   'title': 'Ceremonial Handle (?)'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4c7'),
#   'accessionNumber': '1982.394a, b',
#   'accessionYear': '1982',
#   'classification': 'Ceramics-Containers',
#   'country': 'Guatemala',
#   'measurements': [{'elementMeasurements': {'Height': 37.465}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/314557',
#   'title': 'Seated Figure Censer (Incensario)'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4ca'),
#   'accessionNumber': '1979.206.728',
#   'accessionYear': '1979',
#   'classification': 'Ceramics-Sculpture',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 3.81,
#                                             'Height': 20.7169,
#                                             'Width': 5.08}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/312915',
#   'title': 'Whistle with the Maize God emerging from a flower'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4cb'),
#   'accessionNumber': '1978.412.57',
#   'accessionYear': '1978',
#   'classification': 'Stone-Ornaments',
#   'country': 'Guatemala',
#   'measurements': [{'elementMeasurements': {'Depth': 8.8900175,
#                                             'Height': 0.63500124,
#                                             'Width': 3.8100076}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/310513',
#   'title': 'Pendant'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4d1'),
#   'accessionNumber': '1979.206.373',
#   'accessionYear': '1979',
#   'classification': 'Ceramics-Musical Instruments',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 8.89,
#                                             'Height': 18.1769,
#                                             'Width': 12.7}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/312595',
#   'title': 'Seated Female Figure'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4d9'),
#   'accessionNumber': '1985.216.2',
#   'accessionYear': '1985',
#   'classification': 'Stone-Ornaments',
#   'country': 'Guatemala',
#   'measurements': [{'elementMeasurements': {'Depth': 1.2700025,
#                                             'Height': 1.9050038,
#                                             'Width': 7.620015}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/314832',
#   'title': 'Shell Ornament'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4e3'),
#   'accessionNumber': '1978.412.195',
#   'accessionYear': '1978',
#   'classification': 'Stone-Sculpture',
#   'country': 'Guatemala',
#   'measurements': [{'elementMeasurements': {'Depth': 1.5875032,
#                                             'Height': 34.6075,
#                                             'Width': 19.05}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/310644',
#   'title': 'Scepter with Profile Figures'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4e4'),
#   'accessionNumber': '77.8',
#   'accessionYear': '1877',
#   'classification': 'Stone-Sculpture',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Width': 36.83}},
#                    {'elementMeasurements': {'Height': 16.51, 'Width': 36.83}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/307443',
#   'title': 'Fragmentary Relief'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4e5'),
#   'accessionNumber': '1978.412.24',
#   'accessionYear': '1978',
#   'classification': 'Stone-Sculpture',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 23.83}},
#                    {'elementMeasurements': {'Depth': 23.83,
#                                             'Height': 34.925,
#                                             'Width': 30.18}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/310480',
#   'title': 'Head of a Rain God'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc4f4'),
#   'accessionNumber': '2007.134',
#   'accessionYear': '2007',
#   'classification': 'Stone-Ornaments',
#   'country': 'Guatemala or Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 0.9525019,
#                                             'Height': 5.715,
#                                             'Width': 5.397511}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/319873',
#   'title': 'Deity face pendant'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc505'),
#   'accessionNumber': '1979.206.953',
#   'accessionYear': '1979',
#   'classification': 'Ceramics-Musical Instruments',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 9.53,
#                                             'Height': 29.2894,
#                                             'Width': 9.7}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/313151',
#   'title': 'Costumed Figure'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc506'),
#   'accessionNumber': '1995.489a, b',
#   'accessionYear': '1995',
#   'classification': 'Shell-Ornaments',
#   'country': 'Guatemala (?)',
#   'measurements': [{'elementMeasurements': {'Depth': 0.31750062,
#                                             'Height': 5.7150116,
#                                             'Width': 4.7625093}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/317760',
#   'title': 'Pair of carved ornaments depicting the Maize God'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc508'),
#   'accessionNumber': '1979.206.1069',
#   'accessionYear': '1979',
#   'classification': 'Stone-Sculpture',
#   'country': 'Honduras',
#   'measurements': [{'elementMeasurements': {'Depth': 2.31,
#                                             'Height': 10.795,
#                                             'Width': 6.35}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/313262',
#   'title': 'Deity figure'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc50e'),
#   'accessionNumber': '1989.314.15a, b',
#   'accessionYear': '1989',
#   'classification': 'Stone-Ornaments',
#   'country': 'Guatemala',
#   'measurements': [{'elementMeasurements': {'Depth': 0.9525019,
#                                             'Height': 4.7625093,
#                                             'Width': 4.7625093}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/316299',
#   'title': 'Pair of Earflare Frontals'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc51e'),
#   'accessionNumber': '1994.35.591a, b',
#   'accessionYear': '1994',
#   'classification': 'Stone-Ornaments',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Height': 3.175, 'Width': 2.84}},
#                    {'elementMeasurements': {'Width': 2.84}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/317430',
#   'title': 'Earflare Set'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc520'),
#   'accessionNumber': '1994.35.590a, b',
#   'accessionYear': '1994',
#   'classification': 'Stone-Ornaments',
#   'country': 'Mexico',
#   'measurements': [{'elementMeasurements': {'Width': 2.84}},
#                    {'elementMeasurements': {'Height': 3.175, 'Width': 2.84}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/317429',
#   'title': 'Earflare Set'},
#  {'_id': ObjectId('64b5c397eb87d19a04edc53b'),
#   'accessionNumber': '1980.213',
#   'accessionYear': '1980',
#   'classification': 'Ceramics-Containers',
#   'country': 'Guatemala or Mexico',
#   'measurements': [{'elementMeasurements': {'Depth': 12.541275,
#                                             'Height': 11.430023,
#                                             'Width': 12.541275}}],
#   'objectURL': 'https://www.metmuseum.org/art/collection/search/314217',
#   'title': 'Vessel, mythological scene'}]

# %%
# Convert results to DataFrame
mayan_df = pd.DataFrame(mayan_items)

print(len(mayan_df))
mayan_df.head()
# Out:
# 29
#                         _id  accessionNumber accessionYear  \
# 0  64b5c397eb87d19a04edc05e    1979.206.1061          1979
# 1  64b5c397eb87d19a04edc1c5       1987.450.1          1987
# 2  64b5c397eb87d19a04edc214   1999.484.1a, b          1999
# 3  64b5c397eb87d19a04edc21e  1978.412.90a, b          1978
# 4  64b5c397eb87d19a04edc23a     1978.412.206          1978
#
#                         title  \
# 0           Animal Head Hacha
# 1    Bowl, Mythological Scene
# 2         Censer, Seated King
# 3            Whistling vessel
# 4  Vessel, mythological scene
#
#                                         measurements              country  \
# 0  [{'elementMeasurements': {'Depth': 5.08, 'Heig...            Guatemala
# 1   [{'elementMeasurements': {'Height': 10.477521}}]  Guatemala or Mexico
# 2  [{'elementMeasurements': {'Depth': 22.860046, ...            Guatemala
# 3  [{'elementMeasurements': {'Depth': 13.335027, ...  Guatemala or Mexico
# 4  [{'elementMeasurements': {'Depth': 10.636271, ...
#
#         classification                                          objectURL
# 0      Stone-Sculpture  https://www.metmuseum.org/art/collection/searc...
# 1  Ceramics-Containers  https://www.metmuseum.org/art/collection/searc...
# 2  Ceramics-Containers  https://www.metmuseum.org/art/collection/searc...
# 3  Ceramics-Containers  https://www.metmuseum.org/art/collection/searc...
# 4  Ceramics-Containers  https://www.metmuseum.org/art/collection/searc...

# %%
# Build the aggregation pipeline
# Write a match query to find only the documents about artifacts that
# have a classification where "Sculpture" is contained the value, and
# have a width greater than or equal to 10cm and less than 50cm, and
# have a height greater than or equal to 20cm and less than 60cm.
match_query = {'$match': {'measurements.elementMeasurements.Height': {'$gte': 20, '$lt': 60},
               'measurements.elementMeasurements.Width': {'$gte': 10, '$lt': 50},
               'classification': {'$regex': 'Sculpture'}}

# Write an aggregation query that counts the number of documents, grouped by "classification" and "culture"
group_query = {'$group': {'_id': {"classification": "$classification",
                                  "culture": "$culture"},
                          'count': { '$sum': 1 }}}
               

# Create a dictionary that will allow the pipeline to sort by count in descending order


# Put the pipeline together

# %%
# Run the pipeline through the aggregate method, cast the results as a list, and save the results to a variable

# %%
# Print the number of rows in the result
# Out:
# Number of rows in result:  63

# %%
# Print the first 10 results
# Out:
# [{'_id': {'classification': 'Wood-Sculpture', 'culture': 'Baule peoples'},
#   'count': 6},
#  {'_id': {'classification': 'Stone-Sculpture', 'culture': 'Veracruz'},
#   'count': 5},
#  {'_id': {'classification': 'Wood-Sculpture', 'culture': 'Bamana peoples'},
#   'count': 5},
#  {'_id': {'classification': 'Wood-Sculpture', 'culture': 'Senufo peoples'},
#   'count': 4},
#  {'_id': {'classification': 'Stone-Sculpture', 'culture': 'Aztec'}, 'count': 4},
#  {'_id': {'classification': 'Wood-Sculpture', 'culture': ''}, 'count': 4},
#  {'_id': {'classification': 'Wood-Sculpture', 'culture': 'Kwele peoples'},
#   'count': 3},
#  {'_id': {'classification': 'Wood-Sculpture', 'culture': 'Dogon peoples'},
#   'count': 3},
#  {'_id': {'classification': 'Stone-Sculpture', 'culture': 'Maya'}, 'count': 3},
#  {'_id': {'classification': 'Wood-Sculpture', 'culture': 'Bwa peoples'},
#   'count': 3}]

# %%
# Extract the fields from the _id so they're in separate columns in a Pandas DataFrame
# Out:
#    count _id.classification     _id.culture
# 0      6     Wood-Sculpture   Baule peoples
# 1      5    Stone-Sculpture        Veracruz
# 2      5     Wood-Sculpture  Bamana peoples
# 3      4     Wood-Sculpture  Senufo peoples
# 4      4    Stone-Sculpture           Aztec

# %%
# Rename the columns
# Out:
#    number of artifacts   classification         culture
# 0                    6   Wood-Sculpture   Baule peoples
# 1                    5  Stone-Sculpture        Veracruz
# 2                    5   Wood-Sculpture  Bamana peoples
# 3                    4   Wood-Sculpture  Senufo peoples
# 4                    4  Stone-Sculpture           Aztec

# %%
# Reorder the columns


# Print the first 10 rows of the DataFrame
# Out:
#     classification         culture  number of artifacts
# 0   Wood-Sculpture   Baule peoples                    6
# 1  Stone-Sculpture        Veracruz                    5
# 2   Wood-Sculpture  Bamana peoples                    5
# 3   Wood-Sculpture  Senufo peoples                    4
# 4  Stone-Sculpture           Aztec                    4
# 5   Wood-Sculpture                                    4
# 6   Wood-Sculpture   Kwele peoples                    3
# 7   Wood-Sculpture   Dogon peoples                    3
# 8  Stone-Sculpture            Maya                    3
# 9   Wood-Sculpture     Bwa peoples                    3

# %% [markdown]
# Data Source: [The Metropolitan Museum of Art](https://www.metmuseum.org/) (2022). The Metropolitan Museum of Art Collection API https://metmuseum.github.io/. Licensed under the [Creative Commons 0 License](https://creativecommons.org/publicdomain/zero/1.0/).<br />
# Accessed Oct 3, 2022. Data collected from departmentId=5 ("Arts of Africa, Oceania, and the Americas") and search string "animal".
