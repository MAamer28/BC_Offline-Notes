# %%
# Import Dependencies
import pandas as pd
from pathlib import Path

# %%
# Create a path to the csv and read it into a Pandas DataFrame
filepath = Path("Resources/movie_scores.csv")

movies_df = pd.read_csv(filepath)
movies_df.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
# 2          64              8.1   7.8             5.0                   4.5
# 3          22              4.7   5.4             5.0                   4.5
# 4          29              3.4   5.1             3.5                   3.0
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# ...

# %%
# Figure out the minimum and maximum IMDB user vote count
raters_df = movies_df.sort_values("IMDB_user_vote_count", ascending=False)
raters_df.head()
# Out:
#                                                 FILM  RottenTomatoes  \
# 14                         The Imitation Game (2014)              90
# 65                                    Birdman (2014)              92
# 88                         Mad Max: Fury Road (2015)              97
# 74  The Hobbit: The Battle of the Five Armies (2014)              61
# 44               Kingsman: The Secret Service (2015)              75
#
#     RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 14                   92          73              8.2   8.1             5.0
# 65                   78          88              8.0   7.9             4.0
# 88                   88          89              8.7   8.3             4.5
# 74                   75          59              7.0   7.5             4.5
# 44                   84          58              7.9   7.8             4.5
#
#     Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  IMDB_norm  \
# ...

# %%
# Create bins in which to place values based upon IMDB vote count
bins = [0, 1000, 10000, 25000, 50000, 100000, 150000, 200000, 250000, 300000, 350000]
# Create labels for these bins
bin_labels = ["Under 1,000 Voters", "1,000 to 10,000 Votes", "10K to 25K Votes", "25K to 50K Votes", "50K to 100K Votes", 
              "100K to 150K Votes", "150K to 200K Votes", "200K to 250K Votes", "250K to 300K Votes", "Greater than 300K Votes"]

# %%
# Slice the data and place it into bins
raters_df["IMDB Popularity"] = pd.cut(raters_df["IMDB_user_vote_count"], bins, labels=bin_labels)

# %%
# Place the data series into a new column inside of the DataFrame
raters_df.head()
# Out:
#                                                 FILM  RottenTomatoes  \
# 14                         The Imitation Game (2014)              90
# 65                                    Birdman (2014)              92
# 88                         Mad Max: Fury Road (2015)              97
# 74  The Hobbit: The Battle of the Five Armies (2014)              61
# 44               Kingsman: The Secret Service (2015)              75
#
#     RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  Fandango_Stars  \
# 14                   92          73              8.2   8.1             5.0
# 65                   78          88              8.0   7.9             4.0
# 88                   88          89              8.7   8.3             4.5
# 74                   75          59              7.0   7.5             4.5
# 44                   84          58              7.9   7.8             4.5
#
#     Fandango_Ratingvalue  RT_norm  RT_user_norm  ...  RT_norm_round  \
# ...

# %%
# Create a GroupBy object based upon "IMDB User Votes Group"
IMDB_df = raters_df.groupby("IMDB Popularity")

print(IMDB_df["IMDB Popularity"].count())

# Find how many rows fall into each bin


# Get the average of each of the first 5 rating columns within the GroupBy object
IMDB_df[["RottenTomatoes", "RottenTomatoes_User", "Metacritic", "Metacritic_User", "IMDB"]].mean()
# Out:
# IMDB Popularity
# Under 1,000 Voters          7
# 1,000 to 10,000 Votes      39
# 10K to 25K Votes           44
# 25K to 50K Votes           24
# 50K to 100K Votes          16
# 100K to 150K Votes          5
# 150K to 200K Votes          2
# 200K to 250K Votes          2
# 250K to 300K Votes          5
# Greater than 300K Votes     2
# Name: IMDB Popularity, dtype: int64
#                          RottenTomatoes  RottenTomatoes_User  Metacritic  \
# IMDB Popularity
# Under 1,000 Voters            80.142857            72.428571   68.285714
# 1,000 to 10,000 Votes         62.589744            66.666667   60.410256
# 10K to 25K Votes              55.090909            56.886364   55.568182
# 25K to 50K Votes              55.833333            59.916667   54.791667
# 50K to 100K Votes             67.875000            69.375000   63.125000
# 100K to 150K Votes            40.400000            57.400000   45.400000
# 150K to 200K Votes            58.500000            64.000000   62.000000
# ...
